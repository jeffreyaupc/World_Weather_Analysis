# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | youghal
# Processing Record 2 of Set 1 | lavrentiya
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | quthing
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | vila velha
# Processing Record 7 of Set 1 | bilibino
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | tual
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | lagoa
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | skjervoy
# Processing Record 16 of Set 1 | lienz
# Processing Record 17 of Set 1 | katherine
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | wuning
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | salalah
# Processing Record 27 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | coquimbo
# Processing Record 30 of Set 1 | adrar
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | chapleau
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | lincoln
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | henties bay
# Processing Record 39 of Set 1 | rio grande
# Processing Record 40 of Set 1 | lake cowichan
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | antofagasta
# Processing Record 43 of Set 1 | padang
# Processing Record 44 of Set 1 | dimitrovgrad
# Processing Record 45 of Set 1 | namibe
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | atbasar
# Processing Record 50 of Set 1 | solnechnyy
# Processing Record 1 of Set 2 | yeniseysk
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | gasa
# Processing Record 4 of Set 2 | katsuura
# Processing Record 5 of Set 2 | laguna
# Processing Record 6 of Set 2 | vestmanna
# Processing Record 7 of Set 2 | ubrique
# Processing Record 8 of Set 2 | sayyan
# Processing Record 9 of Set 2 | khandyga
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | rocha
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | bocaiuva
# Processing Record 16 of Set 2 | te anau
# Processing Record 17 of Set 2 | jelenia gora
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | general roca
# Processing Record 20 of Set 2 | berlevag
# Processing Record 21 of Set 2 | aksu
# Processing Record 22 of Set 2 | zverinogolovskoye
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | mahaicony
# City not found. Skipping...
# Processing Record 25 of Set 2 | areosa
# Processing Record 26 of Set 2 | mutoko
# Processing Record 27 of Set 2 | miranda
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | gazanjyk
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | quixada
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | teahupoo
# Processing Record 34 of Set 2 | sharanga
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | santiago del estero
# Processing Record 38 of Set 2 | lasa
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | shelburne
# Processing Record 41 of Set 2 | kavieng
# Processing Record 42 of Set 2 | mandurah
# Processing Record 43 of Set 2 | vysokogornyy
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | lamar
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | port moresby
# Processing Record 48 of Set 2 | itarema
# Processing Record 49 of Set 2 | gariaband
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | sobolevo
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | wilmington
# Processing Record 6 of Set 3 | arbuzynka
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | pevek
# Processing Record 12 of Set 3 | muyezerskiy
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | marawi
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | umba
# Processing Record 21 of Set 3 | saint george
# Processing Record 22 of Set 3 | havelock
# Processing Record 23 of Set 3 | tocopilla
# Processing Record 24 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 3 | inta
# Processing Record 26 of Set 3 | hasaki
# Processing Record 27 of Set 3 | tarrafal
# Processing Record 28 of Set 3 | svetlaya
# Processing Record 29 of Set 3 | batagay-alyta
# Processing Record 30 of Set 3 | labuhan
# Processing Record 31 of Set 3 | colares
# Processing Record 32 of Set 3 | tiksi
# Processing Record 33 of Set 3 | lerwick
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | amarillo
# Processing Record 36 of Set 3 | tautira
# Processing Record 37 of Set 3 | ilinskiy
# Processing Record 38 of Set 3 | bilma
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | nome
# Processing Record 42 of Set 3 | nortelandia
# Processing Record 43 of Set 3 | pochutla
# Processing Record 44 of Set 3 | akyab
# Processing Record 45 of Set 3 | ponta delgada
# Processing Record 46 of Set 3 | ternate
# Processing Record 47 of Set 3 | nemyriv
# Processing Record 48 of Set 3 | san andres
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | sinnamary
# Processing Record 1 of Set 4 | waddan
# Processing Record 2 of Set 4 | karpathos
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | bluff
# Processing Record 5 of Set 4 | kruisfontein
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | belyy yar
# Processing Record 8 of Set 4 | bethel
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | denpasar
# Processing Record 11 of Set 4 | rawah
# Processing Record 12 of Set 4 | oranjemund
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | port blair
# Processing Record 15 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | wanning
# Processing Record 21 of Set 4 | amapa
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | north bend
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 4 | touros
# Processing Record 28 of Set 4 | salinopolis
# Processing Record 29 of Set 4 | olga
# Processing Record 30 of Set 4 | masterton
# Processing Record 31 of Set 4 | pangody
# Processing Record 32 of Set 4 | oistins
# Processing Record 33 of Set 4 | altay
# Processing Record 34 of Set 4 | gamba
# Processing Record 35 of Set 4 | novosheshminsk
# Processing Record 36 of Set 4 | naze
# Processing Record 37 of Set 4 | teberda
# Processing Record 38 of Set 4 | shitanjing
# Processing Record 39 of Set 4 | pathein
# Processing Record 40 of Set 4 | devyatka
# City not found. Skipping...
# Processing Record 41 of Set 4 | tabas
# Processing Record 42 of Set 4 | ulaangom
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 4 | torbay
# Processing Record 46 of Set 4 | teya
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | yangambi
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | davila
# Processing Record 1 of Set 5 | novopokrovka
# Processing Record 2 of Set 5 | umm kaddadah
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | grafton
# Processing Record 5 of Set 5 | tuy hoa
# Processing Record 6 of Set 5 | port elizabeth
# Processing Record 7 of Set 5 | kushmurun
# Processing Record 8 of Set 5 | general salgado
# Processing Record 9 of Set 5 | sitka
# Processing Record 10 of Set 5 | shimoda
# Processing Record 11 of Set 5 | davidson
# Processing Record 12 of Set 5 | walvis bay
# Processing Record 13 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 5 | okha
# Processing Record 15 of Set 5 | athabasca
# Processing Record 16 of Set 5 | kulhudhuffushi
# Processing Record 17 of Set 5 | mandalgovi
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | kiunga
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | mecca
# Processing Record 24 of Set 5 | bouafle
# Processing Record 25 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | pampierstad
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | kjollefjord
# Processing Record 32 of Set 5 | russell
# Processing Record 33 of Set 5 | hambantota
# Processing Record 34 of Set 5 | eyl
# Processing Record 35 of Set 5 | iquique
# Processing Record 36 of Set 5 | mapiri
# Processing Record 37 of Set 5 | san felix
# Processing Record 38 of Set 5 | khor
# Processing Record 39 of Set 5 | nanortalik
# Processing Record 40 of Set 5 | trat
# Processing Record 41 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | dzhebariki-khaya
# Processing Record 44 of Set 5 | flin flon
# Processing Record 45 of Set 5 | almaznyy
# Processing Record 46 of Set 5 | bubaque
# Processing Record 47 of Set 5 | taguatinga
# Processing Record 48 of Set 5 | east london
# Processing Record 49 of Set 5 | bandarbeyla
# Processing Record 50 of Set 5 | sherpur
# Processing Record 1 of Set 6 | gladstone
# Processing Record 2 of Set 6 | otofuke
# Processing Record 3 of Set 6 | kropotkin
# Processing Record 4 of Set 6 | coihaique
# Processing Record 5 of Set 6 | vanimo
# Processing Record 6 of Set 6 | sorong
# Processing Record 7 of Set 6 | dubbo
# Processing Record 8 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 9 of Set 6 | taranagar
# Processing Record 10 of Set 6 | listvyanka
# Processing Record 11 of Set 6 | young
# Processing Record 12 of Set 6 | kerema
# Processing Record 13 of Set 6 | phumi samraong
# City not found. Skipping...
# Processing Record 14 of Set 6 | songea
# Processing Record 15 of Set 6 | bayanday
# Processing Record 16 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 6 | igualada
# Processing Record 19 of Set 6 | saint-augustin
# Processing Record 20 of Set 6 | tarazona
# Processing Record 21 of Set 6 | andorra la vella
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | norsup
# Processing Record 24 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | arraial do cabo
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | san francisco
# Processing Record 30 of Set 6 | daru
# Processing Record 31 of Set 6 | longyearbyen
# Processing Record 32 of Set 6 | miraflores
# Processing Record 33 of Set 6 | saint anthony
# Processing Record 34 of Set 6 | prince rupert
# Processing Record 35 of Set 6 | malanje
# Processing Record 36 of Set 6 | labytnangi
# Processing Record 37 of Set 6 | gafanha da encarnacao
# Processing Record 38 of Set 6 | fereydunshahr
# Processing Record 39 of Set 6 | wewak
# Processing Record 40 of Set 6 | puerto escondido
# Processing Record 41 of Set 6 | witu
# Processing Record 42 of Set 6 | kungurtug
# Processing Record 43 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 44 of Set 6 | maridi
# Processing Record 45 of Set 6 | barra patuca
# Processing Record 46 of Set 6 | nadym
# Processing Record 47 of Set 6 | manokwari
# Processing Record 48 of Set 6 | mayo
# Processing Record 49 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 6 | goderich
# Processing Record 1 of Set 7 | kirksville
# Processing Record 2 of Set 7 | staryy nadym
# Processing Record 3 of Set 7 | saint-louis
# Processing Record 4 of Set 7 | eydhafushi
# Processing Record 5 of Set 7 | sur
# Processing Record 6 of Set 7 | gushikawa
# Processing Record 7 of Set 7 | saint-pierre
# Processing Record 8 of Set 7 | swellendam
# Processing Record 9 of Set 7 | paamiut
# Processing Record 10 of Set 7 | trairi
# Processing Record 11 of Set 7 | donskoye
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | sungairaya
# Processing Record 14 of Set 7 | cockburn town
# Processing Record 15 of Set 7 | mulege
# Processing Record 16 of Set 7 | tukrah
# Processing Record 17 of Set 7 | maningrida
# Processing Record 18 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 19 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 7 | sibolga
# Processing Record 21 of Set 7 | tambovka
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 7 | usinsk
# Processing Record 25 of Set 7 | guarda
# Processing Record 26 of Set 7 | sola
# Processing Record 27 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 7 | uvinza
# Processing Record 29 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 7 | sao jose da coroa grande
# Processing Record 31 of Set 7 | aci castello
# Processing Record 32 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 33 of Set 7 | isla vista
# Processing Record 34 of Set 7 | columbus
# Processing Record 35 of Set 7 | reyes
# Processing Record 36 of Set 7 | gizo
# Processing Record 37 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 7 | atar
# Processing Record 40 of Set 7 | juneau
# Processing Record 41 of Set 7 | narsaq
# Processing Record 42 of Set 7 | kozhva
# Processing Record 43 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 7 | finote selam
# Processing Record 45 of Set 7 | kasra
# City not found. Skipping...
# Processing Record 46 of Set 7 | riyadh
# Processing Record 47 of Set 7 | hami
# Processing Record 48 of Set 7 | cherskiy
# Processing Record 49 of Set 7 | camacha
# Processing Record 50 of Set 7 | ostrovnoy
# Processing Record 1 of Set 8 | keti bandar
# Processing Record 2 of Set 8 | los llanos de aridane
# Processing Record 3 of Set 8 | mizan teferi
# Processing Record 4 of Set 8 | aguada de pasajeros
# Processing Record 5 of Set 8 | vestmannaeyjar
# Processing Record 6 of Set 8 | matara
# Processing Record 7 of Set 8 | yuzhnyy
# Processing Record 8 of Set 8 | french harbor
# Processing Record 9 of Set 8 | bundaberg
# Processing Record 10 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 8 | colac
# Processing Record 12 of Set 8 | grande-synthe
# Processing Record 13 of Set 8 | nantucket
# Processing Record 14 of Set 8 | ilulissat
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | norman wells
# Processing Record 17 of Set 8 | marzuq
# Processing Record 18 of Set 8 | acapulco
# Processing Record 19 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 8 | lesozavodsk
# Processing Record 21 of Set 8 | simpang
# Processing Record 22 of Set 8 | waverly
# Processing Record 23 of Set 8 | portland
# Processing Record 24 of Set 8 | codrington
# Processing Record 25 of Set 8 | namatanai
# Processing Record 26 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 8 | guider
# Processing Record 28 of Set 8 | baykit
# Processing Record 29 of Set 8 | katobu
# Processing Record 30 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 31 of Set 8 | vanavara
# Processing Record 32 of Set 8 | acari
# Processing Record 33 of Set 8 | grindavik
# Processing Record 34 of Set 8 | tselinnoye
# Processing Record 35 of Set 8 | beloha
# Processing Record 36 of Set 8 | fukue
# Processing Record 37 of Set 8 | ewa beach
# Processing Record 38 of Set 8 | gejiu
# Processing Record 39 of Set 8 | ilheus
# Processing Record 40 of Set 8 | pemangkat
# Processing Record 41 of Set 8 | faya
# Processing Record 42 of Set 8 | kudahuvadhoo
# Processing Record 43 of Set 8 | darhan
# Processing Record 44 of Set 8 | vila
# Processing Record 45 of Set 8 | sandwick
# Processing Record 46 of Set 8 | copiapo
# Processing Record 47 of Set 8 | guerrero negro
# Processing Record 48 of Set 8 | komsomolskiy
# Processing Record 49 of Set 8 | avera
# Processing Record 50 of Set 8 | kedgwick
# Processing Record 1 of Set 9 | santa maria
# Processing Record 2 of Set 9 | zanjan
# Processing Record 3 of Set 9 | sale
# Processing Record 4 of Set 9 | yelan
# Processing Record 5 of Set 9 | markova
# Processing Record 6 of Set 9 | methoni
# Processing Record 7 of Set 9 | vila franca do campo
# Processing Record 8 of Set 9 | seoul
# Processing Record 9 of Set 9 | dukat
# Processing Record 10 of Set 9 | teknaf
# Processing Record 11 of Set 9 | hervey bay
# Processing Record 12 of Set 9 | saquena
# Processing Record 13 of Set 9 | mehamn
# Processing Record 14 of Set 9 | yar-sale
# Processing Record 15 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 9 | banovce
# City not found. Skipping...
# Processing Record 17 of Set 9 | arauca
# Processing Record 18 of Set 9 | kaeo
# Processing Record 19 of Set 9 | nueva italia
# Processing Record 20 of Set 9 | karratha
# Processing Record 21 of Set 9 | neepawa
# Processing Record 22 of Set 9 | fairbanks
# Processing Record 23 of Set 9 | akhtubinsk
# Processing Record 24 of Set 9 | bida
# Processing Record 25 of Set 9 | margate
# Processing Record 26 of Set 9 | konstantinovsk
# Processing Record 27 of Set 9 | dingle
# Processing Record 28 of Set 9 | egvekinot
# Processing Record 29 of Set 9 | champerico
# Processing Record 30 of Set 9 | kununurra
# Processing Record 31 of Set 9 | orlovskiy
# Processing Record 32 of Set 9 | batie
# Processing Record 33 of Set 9 | mount gambier
# Processing Record 34 of Set 9 | bay roberts
# Processing Record 35 of Set 9 | ixtapa
# Processing Record 36 of Set 9 | inhambane
# Processing Record 37 of Set 9 | balakhta
# Processing Record 38 of Set 9 | daitari
# Processing Record 39 of Set 9 | chernyshevskiy
# Processing Record 40 of Set 9 | leh
# Processing Record 41 of Set 9 | airai
# Processing Record 42 of Set 9 | khani
# Processing Record 43 of Set 9 | keflavik
# Processing Record 44 of Set 9 | daverdisse
# Processing Record 45 of Set 9 | anadyr
# Processing Record 46 of Set 9 | santa rosa
# Processing Record 47 of Set 9 | russellville
# Processing Record 48 of Set 9 | emirdag
# Processing Record 49 of Set 9 | leningradskiy
# Processing Record 50 of Set 9 | yuanping
# Processing Record 1 of Set 10 | qasigiannguit
# Processing Record 2 of Set 10 | sanghar
# Processing Record 3 of Set 10 | cheney
# Processing Record 4 of Set 10 | mogadishu
# Processing Record 5 of Set 10 | bambous virieux
# Processing Record 6 of Set 10 | huarmey
# Processing Record 7 of Set 10 | chumikan
# Processing Record 8 of Set 10 | uberlandia
# Processing Record 9 of Set 10 | dwarka
# Processing Record 10 of Set 10 | zaysan
# Processing Record 11 of Set 10 | dawson creek
# Processing Record 12 of Set 10 | palmer
# Processing Record 13 of Set 10 | moirang
# Processing Record 14 of Set 10 | ngunguru
# Processing Record 15 of Set 10 | xuddur
# Processing Record 16 of Set 10 | maltahohe
# Processing Record 17 of Set 10 | emerald
# Processing Record 18 of Set 10 | neiafu
# Processing Record 19 of Set 10 | port hawkesbury
# Processing Record 20 of Set 10 | chlorakas
# Processing Record 21 of Set 10 | hofn
# Processing Record 22 of Set 10 | manicore
# Processing Record 23 of Set 10 | vilyuysk
# Processing Record 24 of Set 10 | tonekabon
# Processing Record 25 of Set 10 | dalianwan
# Processing Record 26 of Set 10 | nokia
# Processing Record 27 of Set 10 | mwense
# Processing Record 28 of Set 10 | buraydah
# Processing Record 29 of Set 10 | khash
# Processing Record 30 of Set 10 | mount isa
# Processing Record 31 of Set 10 | sampit
# Processing Record 32 of Set 10 | shelkovskaya
# Processing Record 33 of Set 10 | ossora
# Processing Record 34 of Set 10 | banda aceh
# Processing Record 35 of Set 10 | north platte
# Processing Record 36 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 10 | balkanabat
# Processing Record 38 of Set 10 | bonavista
# Processing Record 39 of Set 10 | pailon
# Processing Record 40 of Set 10 | srandakan
# Processing Record 41 of Set 10 | nilanga
# Processing Record 42 of Set 10 | waipawa
# Processing Record 43 of Set 10 | sompeta
# Processing Record 44 of Set 10 | baculin
# Processing Record 45 of Set 10 | sars
# Processing Record 46 of Set 10 | verrettes
# Processing Record 47 of Set 10 | namchi
# Processing Record 48 of Set 10 | derzhavinsk
# Processing Record 49 of Set 10 | grand gaube
# Processing Record 50 of Set 10 | syamzha
# Processing Record 1 of Set 11 | ajdabiya
# Processing Record 2 of Set 11 | gravdal
# Processing Record 3 of Set 11 | maragogi
# Processing Record 4 of Set 11 | marsa matruh
# Processing Record 5 of Set 11 | herzogenbuchsee
# Processing Record 6 of Set 11 | gorontalo
# Processing Record 7 of Set 11 | nevers
# Processing Record 8 of Set 11 | harrismith
# Processing Record 9 of Set 11 | kisangani
# Processing Record 10 of Set 11 | uvarovo
# Processing Record 11 of Set 11 | kabare
# Processing Record 12 of Set 11 | bontang
# Processing Record 13 of Set 11 | golden gate
# Processing Record 14 of Set 11 | chicago
# Processing Record 15 of Set 11 | nishihara
# Processing Record 16 of Set 11 | constitucion
# Processing Record 17 of Set 11 | urumqi
# Processing Record 18 of Set 11 | sao joao da barra
# Processing Record 19 of Set 11 | gannan
# Processing Record 20 of Set 11 | ondangwa
# Processing Record 21 of Set 11 | yurya
# City not found. Skipping...
# Processing Record 22 of Set 11 | praia da vitoria
# Processing Record 23 of Set 11 | xiuyan
# Processing Record 24 of Set 11 | aykhal
# Processing Record 25 of Set 11 | imbituba
# Processing Record 26 of Set 11 | cabo san lucas
# Processing Record 27 of Set 11 | tagusao
# Processing Record 28 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 11 | okhotsk
# Processing Record 30 of Set 11 | kirakira
# Processing Record 31 of Set 11 | sovetskiy
# Processing Record 32 of Set 11 | vostok
# Processing Record 33 of Set 11 | dandong
# Processing Record 34 of Set 11 | cairns
# Processing Record 35 of Set 11 | conceicao do castelo
# Processing Record 36 of Set 11 | bereda
# Processing Record 37 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 11 | viedma
# Processing Record 39 of Set 11 | sakakah
# Processing Record 40 of Set 11 | jumla
# Processing Record 41 of Set 11 | navolato
# Processing Record 42 of Set 11 | bayir
# Processing Record 43 of Set 11 | doha
# Processing Record 44 of Set 11 | hovd
# Processing Record 45 of Set 11 | valleyview
# Processing Record 46 of Set 11 | erdenet
# Processing Record 47 of Set 11 | broome
# Processing Record 48 of Set 11 | nsoko
# Processing Record 49 of Set 11 | dalby
# Processing Record 50 of Set 11 | curillo
# Processing Record 1 of Set 12 | monrovia
# Processing Record 2 of Set 12 | muncar
# Processing Record 3 of Set 12 | lumding
# Processing Record 4 of Set 12 | bedford
# Processing Record 5 of Set 12 | igarka
# Processing Record 6 of Set 12 | dakor
# Processing Record 7 of Set 12 | beliator
# Processing Record 8 of Set 12 | kijang
# Processing Record 9 of Set 12 | omsukchan
# Processing Record 10 of Set 12 | odweyne
# Processing Record 11 of Set 12 | carepa
# Processing Record 12 of Set 12 | puerto leguizamo
# Processing Record 13 of Set 12 | awjilah
# Processing Record 14 of Set 12 | soto
# Processing Record 15 of Set 12 | tabuk
# Processing Record 16 of Set 12 | lumberton
# Processing Record 17 of Set 12 | wukari
# Processing Record 18 of Set 12 | wembley
# Processing Record 19 of Set 12 | comodoro rivadavia
# Processing Record 20 of Set 12 | fort nelson
# Processing Record 21 of Set 12 | tazovskiy
# Processing Record 22 of Set 12 | coahuayana
# Processing Record 23 of Set 12 | homer
# Processing Record 24 of Set 12 | karonga
# Processing Record 25 of Set 12 | pervomayskoye
# Processing Record 26 of Set 12 | putai
# Processing Record 27 of Set 12 | bulungu
# Processing Record 28 of Set 12 | mossendjo
# Processing Record 29 of Set 12 | fiche
# Processing Record 30 of Set 12 | ostersund
# Processing Record 31 of Set 12 | sulangan
# Processing Record 32 of Set 12 | camalu
# Processing Record 33 of Set 12 | mana
# Processing Record 34 of Set 12 | thunder bay
# Processing Record 35 of Set 12 | salinas
# Processing Record 36 of Set 12 | maldonado
# Processing Record 37 of Set 12 | yarada
# Processing Record 38 of Set 12 | tete
# Processing Record 39 of Set 12 | grenaa
# Processing Record 40 of Set 12 | dickinson
# Processing Record 41 of Set 12 | tromso
# Processing Record 42 of Set 12 | bodden town
# Processing Record 43 of Set 12 | huilong
# Processing Record 44 of Set 12 | micomeseng
# Processing Record 45 of Set 12 | pueblo
# Processing Record 46 of Set 12 | doka
# Processing Record 47 of Set 12 | sioux lookout
# Processing Record 48 of Set 12 | teruel
# Processing Record 49 of Set 12 | dutse
# Processing Record 50 of Set 12 | souillac
# Processing Record 1 of Set 13 | werda
# Processing Record 2 of Set 13 | pangnirtung
# Processing Record 3 of Set 13 | pali
# Processing Record 4 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing Record 5 of Set 13 | puksoozero
# Processing Record 6 of Set 13 | strezhevoy
# Processing Record 7 of Set 13 | kamaishi
# Processing Record 8 of Set 13 | nabire
# Processing Record 9 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 13 | lima
# Processing Record 11 of Set 13 | lodwar
# Processing Record 12 of Set 13 | buchanan
# Processing Record 13 of Set 13 | baoma
# Processing Record 14 of Set 13 | durango
# Processing Record 15 of Set 13 | channel-port aux basques
# Processing Record 16 of Set 13 | burica
# City not found. Skipping...
# Processing Record 17 of Set 13 | sri aman
# Processing Record 18 of Set 13 | le port
# Processing Record 19 of Set 13 | kokopo
# Processing Record 20 of Set 13 | safaga
# Processing Record 21 of Set 13 | san rafael
# Processing Record 22 of Set 13 | xining
# Processing Record 23 of Set 13 | kaduna
# Processing Record 24 of Set 13 | barzas
# Processing Record 25 of Set 13 | westport
# Processing Record 26 of Set 13 | hay river
# Processing Record 27 of Set 13 | terra nova
# Processing Record 28 of Set 13 | oktyabrskoye
# Processing Record 29 of Set 13 | harper
# Processing Record 30 of Set 13 | haines junction
# Processing Record 31 of Set 13 | acala
# Processing Record 32 of Set 13 | mocuba
# Processing Record 33 of Set 13 | hurghada
# Processing Record 34 of Set 13 | yashkino
# Processing Record 35 of Set 13 | pacific grove
# Processing Record 36 of Set 13 | ye
# City not found. Skipping...
# Processing Record 37 of Set 13 | wilkie
# Processing Record 38 of Set 13 | melipilla
# Processing Record 39 of Set 13 | guben
# Processing Record 40 of Set 13 | port lincoln
# Processing Record 41 of Set 13 | boende
# Processing Record 42 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 13 | olden
# Processing Record 44 of Set 13 | pozo colorado
# Processing Record 45 of Set 13 | glendive
# Processing Record 46 of Set 13 | alice springs
# Processing Record 47 of Set 13 | nihommatsu
# Processing Record 48 of Set 13 | ankazoabo
# Processing Record 49 of Set 13 | penzance
# Processing Record 50 of Set 13 | sorland
# Processing Record 1 of Set 14 | richards bay
# Processing Record 2 of Set 14 | ust-kuyga
# Processing Record 3 of Set 14 | kedrovyy
# Processing Record 4 of Set 14 | mahon
# Processing Record 5 of Set 14 | port macquarie
# Processing Record 6 of Set 14 | tommot
# Processing Record 7 of Set 14 | norfolk
# Processing Record 8 of Set 14 | alihe
# Processing Record 9 of Set 14 | caravelas
# Processing Record 10 of Set 14 | rampura
# Processing Record 11 of Set 14 | amga
# Processing Record 12 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 14 | husavik
# Processing Record 15 of Set 14 | copacabana
# Processing Record 16 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 14 | barsovo
# Processing Record 18 of Set 14 | wundanyi
# Processing Record 19 of Set 14 | udachnyy
# Processing Record 20 of Set 14 | pecos
# Processing Record 21 of Set 14 | frontera comalapa
# Processing Record 22 of Set 14 | isugod
# Processing Record 23 of Set 14 | tawau
# Processing Record 24 of Set 14 | benghazi
# Processing Record 25 of Set 14 | lazaro cardenas
# Processing Record 26 of Set 14 | dolores
# Processing Record 27 of Set 14 | hermosillo
# Processing Record 28 of Set 14 | ulaanbaatar
# Processing Record 29 of Set 14 | forbes
# Processing Record 30 of Set 14 | severomorsk
# Processing Record 31 of Set 14 | kilrush
# Processing Record 32 of Set 14 | knysna
# Processing Record 33 of Set 14 | valparaiso
# Processing Record 34 of Set 14 | xadani
# City not found. Skipping...
# Processing Record 35 of Set 14 | ciudad del maiz
# Processing Record 36 of Set 14 | priiskovyy
# Processing Record 37 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 14 | korla
# Processing Record 39 of Set 14 | massaguet
# Processing Record 40 of Set 14 | kahului
# Processing Record 41 of Set 14 | lleida
# Processing Record 42 of Set 14 | coxim
# Processing Record 43 of Set 14 | humaita
# Processing Record 44 of Set 14 | araceli
# Processing Record 45 of Set 14 | noumea
# Processing Record 46 of Set 14 | mafeteng
# Processing Record 47 of Set 14 | rayong
# Processing Record 48 of Set 14 | chapais
# Processing Record 49 of Set 14 | pitimbu
# Processing Record 50 of Set 14 | ramshir
# Processing Record 1 of Set 15 | podyuga
# Processing Record 2 of Set 15 | bolitoc
# Processing Record 3 of Set 15 | buala
# Processing Record 4 of Set 15 | poum
# Processing Record 5 of Set 15 | wa
# City not found. Skipping...
# Processing Record 6 of Set 15 | malakal
# Processing Record 7 of Set 15 | evensk
# Processing Record 8 of Set 15 | toora-khem
# Processing Record 9 of Set 15 | mudyuga
# City not found. Skipping...
# Processing Record 10 of Set 15 | staraya mayna
# Processing Record 11 of Set 15 | olafsvik
# Processing Record 12 of Set 15 | quatre cocos
# Processing Record 13 of Set 15 | miri
# Processing Record 14 of Set 15 | todos santos
# Processing Record 15 of Set 15 | honningsvag
# Processing Record 16 of Set 15 | zhezkazgan
# Processing Record 17 of Set 15 | elizabeth city
# Processing Record 18 of Set 15 | flinders
# Processing Record 19 of Set 15 | kudat
# Processing Record 20 of Set 15 | sangar
# Processing Record 21 of Set 15 | bin qirdan
# Processing Record 22 of Set 15 | presque isle
# Processing Record 23 of Set 15 | uirauna
# Processing Record 24 of Set 15 | bafoulabe
# Processing Record 25 of Set 15 | san cristobal
# Processing Record 26 of Set 15 | srivardhan
# Processing Record 27 of Set 15 | rawson
# Processing Record 28 of Set 15 | bollnas
# Processing Record 29 of Set 15 | paravur
# Processing Record 30 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 31 of Set 15 | novikovo
# Processing Record 32 of Set 15 | kolokani
# Processing Record 33 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 15 | lodja
# Processing Record 35 of Set 15 | maroua
# Processing Record 36 of Set 15 | ancud
# Processing Record 37 of Set 15 | elban
# Processing Record 38 of Set 15 | northam
# Processing Record 39 of Set 15 | lata
# Processing Record 40 of Set 15 | west wendover
# Processing Record 41 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 15 | raudeberg
# Processing Record 43 of Set 15 | san jeronimo
# Processing Record 44 of Set 15 | artyk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Youghal  51.9500   -7.8506     41.00        87          20        6.91
# 1   Lavrentiya  65.5833 -171.0000      6.12        89         100       10.40
# 2    Busselton -33.6500  115.3333     64.99        89         100        5.01
# 3      Quthing -30.4000   27.7003     53.37        51           3        2.06
# 4      Qaanaaq  77.4840  -69.3632    -20.63        77          35        7.47
# 5   Vila Velha -20.3297  -40.2925     75.20        88          75        4.61
# 6     Bilibino  68.0546  166.4372      1.08        75          26        0.49
# 7         Hilo  19.7297 -155.0900     73.00        83          90       11.50
# 8    Cape Town -33.9258   18.4232     66.00        94          75        6.91
# 9  Port Alfred -33.5906   26.8910     60.98        82           1       10.98
#
#   Country Current Description
# 0      IE          few clouds
# 1      RU     overcast clouds
# 2      AU          light rain
# 3      LS           clear sky
# 4      GL    scattered clouds
# 5      BR       broken clouds
# 6      RU    scattered clouds
# 7      US       moderate rain
# 8      ZA       broken clouds
# 9      ZA           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Youghal      IE  51.9500   -7.8506     41.00        87          20
# 1   Lavrentiya      RU  65.5833 -171.0000      6.12        89         100
# 2    Busselton      AU -33.6500  115.3333     64.99        89         100
# 3      Quthing      LS -30.4000   27.7003     53.37        51           3
# 4      Qaanaaq      GL  77.4840  -69.3632    -20.63        77          35
# 5   Vila Velha      BR -20.3297  -40.2925     75.20        88          75
# 6     Bilibino      RU  68.0546  166.4372      1.08        75          26
# 7         Hilo      US  19.7297 -155.0900     73.00        83          90
# 8    Cape Town      ZA -33.9258   18.4232     66.00        94          75
# 9  Port Alfred      ZA -33.5906   26.8910     60.98        82           1
#
#    Wind Speed Current Description
# 0        6.91          few clouds
# 1       10.40     overcast clouds
# 2        5.01          light rain
# 3        2.06           clear sky
# 4        7.47    scattered clouds
# 5        4.61       broken clouds
# 6        0.49    scattered clouds
# 7       11.50       moderate rain
# 8        6.91       broken clouds
# 9       10.98           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
